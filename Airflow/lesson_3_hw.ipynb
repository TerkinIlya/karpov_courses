# %%
import pandas as pd
import numpy as np

# %%
vg_data = pd.read_csv('/content/drive/MyDrive/Karpov_Courses/data/games.csv')

# %%
vg_data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
vg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
vg_df = vg_data[vg_data['Year'] == 1994.0]
vg_df.head()
# Out:
#      Rank                            Name Platform    Year         Genre  \
# 71     72             Donkey Kong Country     SNES  1994.0      Platform
# 184   185  Super Mario Land 3: Wario Land       GB  1994.0      Platform
# 305   306                Donkey Kong Land       GB  1994.0      Platform
# 353   354          Doom II: Hell on Earth       PC  1994.0       Shooter
# 389   390               Final Fantasy III     SNES  1994.0  Role-Playing
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 71             Nintendo      4.36      1.71      3.00         0.23
# 184            Nintendo      2.49      0.98      1.57         0.15
# 305            Nintendo      1.97      0.76      1.07         0.11
# 353  Virgin Interactive      2.05      1.40      0.00         0.16
# 389          SquareSoft      0.86      0.00      2.55         0.02
#
#      Global_Sales
# 71           9.30
# 184          5.19
# 305          3.91
# 353          3.61
# 389          3.42

# %%
vg_df.loc[vg_df['Global_Sales'].idxmax()]['Name']
# Out:
# 'Donkey Kong Country'

# %% [markdown]
# ### Игры какого жанра были самыми продаваемыми в Европе? Перечислить все, если их несколько

# %%
vg_df.groupby('Genre', as_index=False).agg({'EU_Sales': 'sum'}).sort_values('EU_Sales', ascending=False).values[0][0]
# Out:
# 'Platform'

# %%
vg_df.groupby('Genre')['EU_Sales'].sum().sort_values(ascending=False).values[0]
# Out:
# 5.7299999999999995

# %% [markdown]
# ### На какой платформе было больше всего игр, которые продались более чем миллионным тиражом в Северной Америке?
# Перечислить все, если их несколько

# %%
vg_df[vg_df['NA_Sales'] > 1.0]['Platform'].value_counts().keys()[0]
# Out:
# 'SNES'

# %% [markdown]
# ### У какого издателя самые высокие средние продажи в Японии?
# Перечислить все, если их несколько

# %%
login = 'i-fedotov'

# %%
for _ in range(15):
  print(1994 + hash(f'{login}') % 23)
# Out:
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001

# %%
vg_df.groupby('Publisher')['JP_Sales'].mean().sort_values(ascending=False).keys()[0]
# Out:
# 'SquareSoft'

# %% [markdown]
# ### Сколько игр продались лучше в Европе, чем в Японии?

# %%
vg_df[vg_df['EU_Sales'] > vg_df['JP_Sales']]['Name'].count()
# Out:
# 21
