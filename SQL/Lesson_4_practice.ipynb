# %%
# !pip install clickhouse-sqlalchemy -q
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.0 MB/s eta 0:00:00
# ...

# %%
from sqlalchemy import create_engine

# %%
db_settings = {'host': 'https://clickhouse.lab.karpov.courses',
               'db_name': 'default',
               'user': 'student',
               'password': 'dpo_python_2020',
               'port': 500
}

# %%
engine_path = f'''clickhouse+native://{db_settings['user']}:{db_settings['password']}@{db_settings['host']}:{db_settings['port']}/{db_settings['db_name']}'''

# %%
engine = create_engine('clickhouse+https://clickhouse.lab.karpov.courses')
engine
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# <ipython-input-59-4ed41a30b5df> in <cell line: 1>()
# ----> 1 engine = create_engine('clickhouse+https://clickhouse.lab.karpov.courses')
#       2 engine
#
# <string> in create_engine(url, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     373                         stacklevel=3,
#     374                     )
# --> 375             return fn(*args, **kwargs)
#     376
#     377         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# /usr/local/lib/python3.9/dist-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#     516     u, plugins, kwargs = u._instantiate_plugins(kwargs)
#     517
# --> 518     entrypoint = u._get_entrypoint()
#     519     dialect_cls = entrypoint.get_dialect_cls(u)
#     520
#
# ...

# %%
# !pip install clickhouse-driver
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from clickhouse_driver import Client

# %%
client = Client('http://host:port:https://clickhouse.lab.karpov.courses',
                port=9440,
                user=db_settings['user'],
                password=db_settings['password'],
                database=db_settings['db_name'])

# %%
client.execute('''select * from installs limit 100''')
# Out:
# WARNING:clickhouse_driver.connection:Failed to connect to http://host:port:https://clickhouse.lab.karpov.courses:9440
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/clickhouse_driver/connection.py", line 342, in connect
#     return self._init_connection(host, port)
#   File "/usr/local/lib/python3.9/dist-packages/clickhouse_driver/connection.py", line 306, in _init_connection
#     self.socket = self._create_socket(host, port)
#   File "/usr/local/lib/python3.9/dist-packages/clickhouse_driver/connection.py", line 257, in _create_socket
#     for res in socket.getaddrinfo(host, port, 0, socket.SOCK_STREAM):
#   File "/usr/lib/python3.9/socket.py", line 954, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# socket.gaierror: [Errno -2] Name or service not known
# ---------------------------------------------------------------------------
# ...
