# %%
# !pip install pandahouse -q

# %%
import pandahouse as ph

# %%
connection = dict(database='default',
                  host='https://clickhouse.lab.karpov.courses',
                  user='student',
                  password='dpo_python_2020')

# %%
def select(sql):
    return ph.read_clickhouse(sql, connection=connection)

# %%
query = 'SELECT * FROM checks'
df = ph.read_clickhouse(query, connection=connection)

# %%
df.shape
# Out:
# (56088728, 3)

# %%
sql = '''select InstallationDate as Date, InstallCost * 0.82 as cost_with_nds, Platform, DeviceID, Source, 777 as my_field
from default.installs
where
InstallCost > 0
and Source = 'Source_15'
order by Date asc,
Platform desc,
InstallCost asc
limit 1000'''

# %%
select(sql)
# Out:
#            Date  cost_with_nds Platform              DeviceID     Source  \
# 0    2019-01-01           6.56      iOS   6183133831914283538  Source_15
# 1    2019-01-01          11.48      iOS  17029181341557052119  Source_15
# 2    2019-01-01          14.76      iOS  10621192783043059979  Source_15
# 3    2019-01-01          14.76      iOS   4355870932657028094  Source_15
# 4    2019-01-01          15.58      iOS   4931438194819303125  Source_15
# ..          ...            ...      ...                   ...        ...
# 995  2019-01-02           1.64  android  17573594953613598486  Source_15
# 996  2019-01-02           1.64  android    276942273068666597  Source_15
# 997  2019-01-02           2.46  android   5108935000105113236  Source_15
# 998  2019-01-02           2.46  android   5136496215667711088  Source_15
# 999  2019-01-02           2.46  android   8009857119256387610  Source_15
#
#      my_field
# 0         777
# 1         777
# 2         777
# 3         777
# ...

# %%
sql = '''SELECT
Source, 
 Platform
 FROM installs
 group by Source, Platform'''

# %%
select(sql)
# Out:
#        Source      Platform
# 0   Source_25           iOS
# 1   Source_13           iOS
# 2   Source_11           iOS
# 3   Source_27           iOS
# 4   Source_26       android
# 5   Source_11       android
# 6   Source_16           iOS
# 7   Source_20           iOS
# 8    Source_6           iOS
# 9   Source_14           iOS
# 10   Source_2       android
# 11  Source_17       android
# 12  Source_19           iOS
# 13   Source_8           iOS
# 14  Source_20       android
# 15   Source_8       android
# 16  Source_14       android
# 17   Source_7           iOS
# 18   Source_4       android
# 19  Source_19       android
# 20  Source_23       android
# 21   Source_6       android
# 22  Source_25       android
# 23   Source_9           iOS
# 24  Source_12       android
# 25   Source_1           iOS
# 26  Source_28       android
# 27  Source_27       android
# 28   Source_3       android
# 29  Source_10       android
# 30   Source_9       android
# 31   Source_7  WindowsPhone
# ...
