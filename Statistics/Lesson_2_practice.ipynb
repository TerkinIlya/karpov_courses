# %% [markdown]
# ### ЦПТ

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
height = np.random.normal(50, 16, 30)

# %%
sns.histplot(height)
# Out:
# <Axes: ylabel='Count'>

# %%
height_sample = [np.random.normal(50, 16, 30) for _ in range(500)]

# %%
sns.histplot(np.random.normal(50, 16, 500))
# Out:
# <Axes: ylabel='Count'>

# %%
np.mean(height_sample)
# Out:
# 49.841661025448175

# %% [markdown]
# # Проверка гипотез
# ### Задача 1
# Исследователи утверждают, что среднее время госпитализации при лечении препаратом А равняется 20 дням при сигме = 4.
#
# Мы усомнились в этих результатах и провели собственное исследование, в котором приняло участие 64 пациента, лечащихся препаратом А. У каждого из участников замерялось время госпитализации:
#
#
# $$M = 18.5$$
# $$N = 64$$

# %%
samples = [np.mean(np.random.normal(20, 4, 64)) for _ in range(1000)]

# %%
sns.histplot(samples)
# Out:
# <Axes: ylabel='Count'>

# %%
np.quantile(samples, 0.7, method='midpoint')
# Out:
# 20.24450130440043
